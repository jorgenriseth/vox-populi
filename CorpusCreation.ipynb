# %%
# %load_ext autoreload
# %autoreload 2

# %%
auth = get_tweet_auth()
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
user = 'AdamAfriyie'

# %%
curs = tweepy.Cursor(api.user_timeline, screen_name=user, count=200,
                     tweet_mode='extended').items(5)



with open('test.jsonl', 'w') as f:
    for status in curs:
        tweet = status._json
        json_dump_line(tweet, f)

# %%
# Natural Language Toolkit: Twitter Corpus Reader
#
# Copyright (C) 2001-2019 NLTK Project
# Author: Ewan Klein <ewan@inf.ed.ac.uk>
# URL: <http://nltk.org/>
# For license information, see LICENSE.TXT

"""
A reader for corpora that consist of Tweets. It is assumed that the Tweets
have been serialised into line-delimited JSON.
"""

import json
import os

from six import string_types

from nltk.tokenize import TweetTokenizer

from nltk.corpus.reader.util import StreamBackedCorpusView, concat, ZipFilePathPointer
from nltk.corpus.reader.api import CorpusReader


class TwitterCorpusReader(CorpusReader):
    """
    Reader for corpora that consist of Tweets represented as a list of line-delimited JSON.
    Individual Tweets can be tokenized using the default tokenizer, or by a
    custom tokenizer specified as a parameter to the constructor.
    Construct a new Tweet corpus reader for a set of documents
    located at the given root directory.
    If you made your own tweet collection in a directory called
    `twitter-files`, then you can initialise the reader as::
        from nltk.corpus import TwitterCorpusReader
        reader = TwitterCorpusReader(root='/path/to/twitter-files', '.*\.json')
    However, the recommended approach is to set the relevant directory as the
    value of the environmental variable `TWITTER`, and then invoke the reader
    as follows::
       root = os.environ['TWITTER']
       reader = TwitterCorpusReader(root, '.*\.json')
    If you want to work directly with the raw Tweets, the `json` library can
    be used::
       import json
       for tweet in reader.docs():
           print(json.dumps(tweet, indent=1, sort_keys=True))
    """

    CorpusView = StreamBackedCorpusView
    """
    The corpus view class used by this reader.
    """

    def __init__(
        self, root, fileids=None, word_tokenizer=TweetTokenizer(), encoding="utf8"
    ):
        """
        :param root: The root directory for this corpus.
        :param fileids: A list or regexp specifying the fileids in this corpus.
        :param word_tokenizer: Tokenizer for breaking the text of Tweets into
        smaller units, including but not limited to words.
        """
        CorpusReader.__init__(self, root, fileids, encoding)

        for path in self.abspaths(self._fileids):
            if isinstance(path, ZipFilePathPointer):
                pass
            elif os.path.getsize(path) == 0:
                raise ValueError("File {} is empty".format(path))
        """Check that all user-created corpus files are non-empty."""

        self._word_tokenizer = word_tokenizer

    def docs(self, fileids=None):
        """
        Returns the full Tweet objects, as specified by `Twitter
        documentation on Tweets
        <https://dev.twitter.com/docs/platform-objects/tweets>`_
        :return: the given file(s) as a list of dictionaries deserialised
        from JSON.
        :rtype: list(dict)
        """
        return concat(
            [
                self.CorpusView(path, self._read_tweets, encoding=enc)
                for (path, enc, fileid) in self.abspaths(fileids, True, True)
            ]
        )

    def strings(self, fileids=None):
        """
        Returns only the text content of Tweets in the file(s)
        :return: the given file(s) as a list of Tweets.
        :rtype: list(str)
        """
        fulltweets = self.docs(fileids)
        tweets = []
        for jsono in fulltweets:
            try:
                text = jsono["full_text"]
                if isinstance(text, bytes):
                    text = text.decode(self.encoding)
                tweets.append(text)
            except KeyError:
                pass
        return tweets

    def tokenized(self, fileids=None):
        """
        :return: the given file(s) as a list of the text content of Tweets as
        as a list of words, screenanames, hashtags, URLs and punctuation symbols.
        :rtype: list(list(str))
        """
        tweets = self.strings(fileids)
        tokenizer = self._word_tokenizer
        return [tokenizer.tokenize(t) for t in tweets]

    def raw(self, fileids=None):
        """
        Return the corpora in their raw form.
        """
        if fileids is None:
            fileids = self._fileids
        elif isinstance(fileids, string_types):
            fileids = [fileids]
        return concat([self.open(f).read() for f in fileids])

    def _read_tweets(self, stream):
        """
        Assumes that each line in ``stream`` is a JSON-serialised object.
        """
        tweets = []
        for i in range(10):
            line = stream.readline()
            if not line:
                return tweets
            tweet = json.loads(line)
            tweets.append(tweet)
        return tweets

# %%
# from nltk.corpus.reader import TwitterCorpusReader
corpus = TwitterCorpusReader(root='./testcorpus/', fileids='.*.jsonl')

# %%
corpus.fileids()
# Out:
# ['test.jsonl']

# %%
corpus.tokenized()
# Out:
# [['After',
#   'a',
#   'quiet',
#   'evening',
#   'at',
#   'The',
#   'Barley',
#   'Mow',
#   'at',
#   'Englefield',
#   'Green',
#   ',',
#   'the',
#   'weather',
#   '’',
#   's',
#   'looking',
#   'good',
#   'today',
#   'and',
#   'I',
#   '’',
#   'm',
#   'doing',
#   'some',
#   'casework',
#   'with',
#   'an',
#   'active',
#   'day',
#   'across',
#   'the',
#   'constituency',
#   '.',
#   '@bmenglefield',
#   '@WindsorTories'],
#  ['Good',
#   'news',
#   'for',
#   'the',
#   'UK',
#   '.',
#   'As',
#   'the',
#   'PM',
#   '’',
#   's',
#   'Trade',
#   'Envoy',
#   'to',
#   'Ghana',
#   '&',
#   'Guinea',
#   ',',
#   'I',
#   '’',
#   'm',
#   'very',
#   'much',
#   'aware',
#   'that',
#   'ship',
#   'building',
#   'can',
#   'be',
#   'a',
#   'great',
#   'export',
#   'too',
#   '!',
#   'https://t.co/FJQZ0VYlmC'],
#  ['The',
#   'green',
#   'belt',
#   'helps',
#   'make',
#   'our',
#   'constituency',
#   'a',
#   'beautiful',
#   'place',
#   'to',
#   'live',
#   '.',
#   'So',
#   'I',
#   '’',
#   'm',
#   'delighted',
#   'to',
#   'say',
#   'that',
#   'today',
#   'we',
#   '’',
#   've',
#   'secured',
#   '£',
#   '50k',
#   'from',
#   'Government',
#   ',',
#   'for',
#   'the',
#   'Royal',
#   'Borough',
#   'of',
#   'Windsor',
#   '&',
#   'Maidenhead',
#   'to',
#   'clamp',
#   'down',
#   'on',
#   'illegal',
#   'building',
#   'on',
#   'the',
#   'green',
#   'belt-just',
#   'great',
#   '!',
#   '@rbwm',
#   '@mhclg',
#   '@WindsorTories'],
#  ['🚨',
#   'Attention',
#   'Datchet',
#   '!',
#   '🚨',
#   'Your',
#   'local',
#   '@PostOffice',
#   'is',
#   'in',
#   'dire',
#   'need',
#   'of',
#   'a',
#   'new',
#   'postmaster',
#   '!',
#   'Our',
#   'Post',
#   'Offices',
#   'provide',
#   'a',
#   'vital',
#   'service',
#   'to',
#   'thousands',
#   'of',
#   'consitituents',
#   'and',
#   'help',
#   'preserve',
#   'our',
#   'strong',
#   'local',
#   'communities',
#   '!',
#   '📪',
#   'https://t.co/Jd4GrYVvML'],
#  ['It',
#   '’',
#   's',
#   'Back',
#   'British',
#   'Farming',
#   'Day',
#   'today',
#   '!',
#   '🚜',
#   '🐮',
#   '🐔',
#   '🌾',
#   'Be',
#   'sure',
#   'to',
#   'show',
#   'your',
#   'support',
#   'for',
#   'our',
#   'Great',
#   'British',
#   'Farmers',
#   ',',
#   'many',
#   'of',
#   'whom',
#   'operate',
#   'in',
#   'Windsor',
#   '!',
#   '🇬',
#   '🇧',
#   '#BackBritishFarming']]

# %%
import os
import tweepy
import json

from utils import json_dump_line, get_tweet_auth

class CorpusCreator:
    """
    Class for creating corpus structure and loading tweets
    using tweepy.
    
    Structure:
    -> corpus
    
    ----> screen_name1
    ------> tweet_id1.txt
    ------> tweet_id2.txt
    
    ----> screen_name2
    ------> tweet_id1.txt
    ------> tweet_id2.txt
    .
    .
    
    """
    
    def __init__(self, user_dict=None, rel_path='./',
                rate_limit_wait=True):
        
        # Get an API-object authorized from 'credentials.txt'
        auth = get_tweet_auth()
        self.api = tweepy.API(auth,
                              wait_on_rate_limit=rate_limit_wait,
                              wait_on_rate_limit_notify=rate_limit_wait)
        
        self.root = rel_path + 'corpus/'
        
        # Load mp-file from directory
        if user_dict is None:
            with open('mps.json') as f:
                self.users = json.load(f)
        else:
            self.users = user_dict
        
        # Create root filesystem
        try:
            os.mkdir(self.root)
            print('Directory "corpus created.')
            print()
        except:
            print('Directory "corpus" already exists.')
            print()
            
        
            
    def load_tweets(self, max_items=10000, user=None):
        """
        For all users in self.users, get [max_items] tweets and
        save each to separate files. 
        """
        for name, info in self.users.items():
            try:
                os.mkdir(self.root + info['party'].lower().replace(' ', '_'))
            except FileExistsError:
                pass
            
            filepath = self.root + info['party'].lower().replace(' ', '_')
            filepath = filepath + '/' + name.lower().replace(' ', '')
            try:
                print(f'Reading tweets from {name}')
                user = info['screen_name']
                curs = tweepy.Cursor(self.api.user_timeline,
                                     screen_name=user,
                                     count=200,
                                     ).items(max_items)

                with open(filepath + '.jsonl', 'w') as f:
                    for status in curs:
                        tweet = status._json
                        json_dump_line(tweet, f)
                        
            except tweepy.TweepError as exc:
                print(exc)
                os.remove(filepath + '.jsonl')

# %%
# corpus_creator = CorpusCreator()
# corpus_creator.load_tweets(max_items=5)
# Out:
# Directory "corpus" already exists.
#
# Reading tweets from Adam Afriyie
# Reading tweets from Alan Duncan
# Reading tweets from Alan Mak
# Reading tweets from Alberto Costa
# Reading tweets from Alec Shelbrooke
# Reading tweets from Alex Burghart
# Reading tweets from Alex Chalk
# Reading tweets from Alistair Burt
# Reading tweets from Alok Sharma
# Reading tweets from Alun Cairns
# Reading tweets from Amanda Milling
# Reading tweets from Amber Rudd
# Reading tweets from Andrea Jenkyns
# Reading tweets from Andrea Leadsom
# Reading tweets from Andrew Bowie
# Reading tweets from Andrew Bridgen
# Reading tweets from Andrew Jones
# Reading tweets from Andrew Lewer
# Reading tweets from Andrew Rosindell
# Reading tweets from Andrew Selous
# Reading tweets from Andrew Stephenson
# Reading tweets from Anne Marie Morris
# Reading tweets from Anne Milton
# Reading tweets from Anne-Marie Trevelyan
# Reading tweets from Antoinette Sandbach
# Reading tweets from Ben Bradley
# Reading tweets from Ben Wallace
# Reading tweets from Bernard Jenkin
# Reading tweets from Bim Afolami
# Reading tweets from Bob Blackman
# Reading tweets from Bob Seely
# Reading tweets from Boris Johnson
# Reading tweets from Brandon Lewis
# Reading tweets from Caroline Dinenage
# Reading tweets from Caroline Nokes
# Reading tweets from Caroline Spelman
# Reading tweets from Cheryl Gillan
# Reading tweets from Chloe Smith
# Reading tweets from Chris Green
# Reading tweets from Chris Heaton-Harris
# Reading tweets from Chris Philp
# Reading tweets from Chris Skidmore
# Reading tweets from Christopher Pincher
# Reading tweets from Claire Perry
# Reading tweets from Colin Clark
# Reading tweets from Conor Burns
# Reading tweets from Craig Mackinlay
# Reading tweets from Craig Tracey
# Reading tweets from Craig Whittaker
# Reading tweets from Crispin Blunt
# Reading tweets from Damian Collins
# Reading tweets from Damian Green
# Reading tweets from Damian Hinds
# Reading tweets from Damien Moore
# Reading tweets from Daniel Kawczynski
# Reading tweets from David Amess
# Reading tweets from David Davis
# Reading tweets from David Duguid
# Reading tweets from David Evennett
# Reading tweets from David Gauke
# Reading tweets from David Jones
# Reading tweets from David Lidington
# Reading tweets from David Morris
# Reading tweets from David Mundell
# Reading tweets from David Rutley
# Reading tweets from David T. C. Davies
# Reading tweets from David Warburton
# Reading tweets from Derek Thomas
# Reading tweets from Desmond Swayne
# Reading tweets from Dominic Raab
# Reading tweets from Douglas Ross
# Reading tweets from Dr Andrew Murrison
# Reading tweets from Dr Caroline Johnson
# Reading tweets from Dr Liam Fox
# Reading tweets from Dr Phillip Lee
# Reading tweets from Dr Thérèse Coffey
# Reading tweets from Eddie Hughes
# Reading tweets from Edward Leigh
# Reading tweets from Edward Vaizey
# Reading tweets from Eleanor Laing
# Reading tweets from Elizabeth Truss
# Reading tweets from Esther McVey
# Reading tweets from Gary Streeter
# Reading tweets from Gavin Williamson
# Reading tweets from Geoffrey Cox QC
# Reading tweets from George Freeman
# Reading tweets from George Hollingbery
# Reading tweets from Giles Watling
# Reading tweets from Gillian Keegan
# Reading tweets from Glyn Davies
# Reading tweets from Graham Stuart
# Reading tweets from Grant Shapps
# Reading tweets from Greg Clark
# Reading tweets from Greg Hands
# Reading tweets from Greg Knight
# Reading tweets from Guto Bebb
# Reading tweets from Guy Opperman
# Reading tweets from Harriett Baldwin
# Reading tweets from Heather Wheeler
# Reading tweets from Helen Grant
# Reading tweets from Helen Whately
# Reading tweets from Henry Smith
# Reading tweets from Hugo Swire
# Reading tweets from Huw Merriman
# Reading tweets from Iain Stewart
# Reading tweets from Jack Lopresti
# Reading tweets from Jackie Doyle-Price
# Reading tweets from Jacob Rees-Mogg
# Reading tweets from Jake Berry
# Reading tweets from James Brokenshire
# Reading tweets from James Cartlidge
# Reading tweets from James Cleverly
# Reading tweets from James Duddridge
# Reading tweets from James Gray
# Reading tweets from James Heappey
# Reading tweets from James Morris
# Reading tweets from Jeremy Hunt
# Reading tweets from Jeremy Lefroy
# Reading tweets from Jeremy Wright
# Twitter error response: status code = 401
# Reading tweets from Jesse Norman
# Reading tweets from Jo Churchill
# Reading tweets from John Glen
# Reading tweets from John Howell
# Reading tweets from John Lamont
# Reading tweets from John Penrose
# Reading tweets from John Redwood
# Reading tweets from John Stevenson
# Reading tweets from John Whittingdale
# Reading tweets from Johnny Mercer
# Reading tweets from Jonathan Djanogly
# Reading tweets from Jonathan Lord
# Reading tweets from Joseph Johnson
# Reading tweets from Julia Lopez
# Reading tweets from Julian Knight
# Reading tweets from Julian Smith
# Reading tweets from Justin Tomlinson
# Reading tweets from Justine Greening
# Reading tweets from Keith Simpson
# Reading tweets from Kelly Tolhurst
# Reading tweets from Kemi Badenoch
# Reading tweets from Kevin Foster
# Reading tweets from Kevin Hollinrake
# Reading tweets from Kirstene Hair
# Reading tweets from Kit Malthouse
# Reading tweets from Kwasi Kwarteng
# Reading tweets from Laurence Robertson
# Reading tweets from Lee Benjamin Rowley
# Reading tweets from Leo Docherty
# Reading tweets from Lucy Allan
# Reading tweets from Lucy Frazer
# Reading tweets from Luke Graham
# Reading tweets from Luke Hall
# Reading tweets from Maggie Throup
# Reading tweets from Marcus Fysh
# Reading tweets from Marcus Jones
# Reading tweets from Margot James
# Reading tweets from Maria Caulfield
# Reading tweets from Maria Miller
# Reading tweets from Mark Field
# Reading tweets from Mark Garnier
# Reading tweets from Mark Harper
# Reading tweets from Mark Lancaster
# Reading tweets from Mark Pawsey
# Reading tweets from Mark Prisk
# Reading tweets from Mark Pritchard
# Reading tweets from Mark Spencer
# Reading tweets from Martin Vickers
# Reading tweets from Mary Robinson
# Reading tweets from Matt Warman
# Reading tweets from Matthew Hancock
# Reading tweets from Matthew Offord
# Reading tweets from Mel Stride
# Reading tweets from Michael Ellis
# Reading tweets from Michael Fabricant
# Reading tweets from Michael Gove
# Reading tweets from Michael Tomlinson
# Reading tweets from Michelle Donelan
# Reading tweets from Mike Wood
# Reading tweets from Mims Davies
# Reading tweets from Nadhim Zahawi
# Reading tweets from Nadine Dorries
# Reading tweets from Neil O'Brien
# Reading tweets from Neil Parish
# Reading tweets from Nicholas Soames
# Reading tweets from Nick Gibb
# Reading tweets from Nick Herbert
# Reading tweets from Nick Hurd
# Reading tweets from Nicky Morgan
# Reading tweets from Nigel Adams
# Reading tweets from Nigel Evans
# Reading tweets from Nigel Huddleston
# Reading tweets from Nigel Mills
# Reading tweets from Nusrat Ghani
# Reading tweets from Oliver Heald QC
# Reading tweets from Oliver Letwin
# Reading tweets from Owen Paterson
# Reading tweets from Patrick McLoughlin
# Reading tweets from Paul Masterton
# Reading tweets from Paul Maynard
# Reading tweets from Paul Scully
# Reading tweets from Pauline Latham
# Reading tweets from Penny Mordaunt
# Reading tweets from Peter Aldous
# Reading tweets from Peter Bone
# Reading tweets from Peter Heaton-Jones
# Reading tweets from Philip Davies
# Reading tweets from Philip Dunne
# Reading tweets from Philip Hammond
# Reading tweets from Priti Patel
# Reading tweets from Rachel Maclean
# Reading tweets from Ranil Jayawardena
# Reading tweets from Rebecca Harris
# Reading tweets from Rebecca Pow
# Reading tweets from Rehman Chishti
# Reading tweets from Richard Bacon
# Reading tweets from Richard Benyon
# Reading tweets from Richard Graham
# Reading tweets from Richard Harrington
# Reading tweets from Robert Buckland
# Reading tweets from Robert Courts
# Reading tweets from Robert Halfon
# Reading tweets from Robert Jenrick
# Reading tweets from Robert Neill
# Reading tweets from Robert Syms
# Reading tweets from Robin Walker
# Reading tweets from Roger Gale
# Reading tweets from Rory Stewart
# Reading tweets from Ross Thomson
# Reading tweets from Royston Smith
# Reading tweets from Sajid Javid
# Reading tweets from Sam Gyimah
# Reading tweets from Sarah Newton
# Reading tweets from Scott Mann
# Reading tweets from Seema Kennedy
# Reading tweets from Shailesh Vara
# Reading tweets from Sheryll Murray
# Reading tweets from Simon Clarke
# Reading tweets from Simon Hart
# Reading tweets from Simon Hoare
# Reading tweets from Stephen Barclay
# Reading tweets from Stephen Crabb
# Reading tweets from Stephen Hammond
# Reading tweets from Stephen Kerr
# Reading tweets from Stephen McPartland
# Reading tweets from Stephen Metcalfe
# Reading tweets from Steve Brine
# Reading tweets from Steve Double
# Reading tweets from Steven Baker
# Reading tweets from Stuart Andrew
# Reading tweets from Suella Fernandes
# Reading tweets from Theresa May
# Reading tweets from Tim Loughton
# Reading tweets from Tobias Ellwood
# Reading tweets from Tom Pursglove
# Reading tweets from Tom Tugendhat
# Reading tweets from Tracey Crouch
# Reading tweets from Vicky Ford
# Reading tweets from Victoria Prentis
# Reading tweets from Wendy Morton
# Reading tweets from Will Quince
# Reading tweets from William Cash
# Reading tweets from William Wragg
# Reading tweets from Zac Goldsmith
# Reading tweets from David Simpson
# Reading tweets from Emma Little-Pengelly
# Reading tweets from Gavin Robinson
# Reading tweets from Jeffrey M. Donaldson
# Reading tweets from Jim Shannon
# Reading tweets from Nigel Dodds
# Reading tweets from Paul Girvan
# Reading tweets from Sammy Wilson
# Reading tweets from Caroline Lucas
# Reading tweets from Angela Smith
# Reading tweets from Charlie Elphicke
# Reading tweets from Chris Williamson
# Reading tweets from Frank Field
# Reading tweets from Gavin Shuker
# Reading tweets from Heidi Allen
# Reading tweets from Ian Austin
# Reading tweets from Ivan Lewis
# Reading tweets from Jared O'Mara
# Twitter error response: status code = 401
# Reading tweets from John Woodcock
# Reading tweets from Luciana Berger
# Reading tweets from Nick Boles
# Reading tweets from Sarah Wollaston
# Reading tweets from Stephen Lloyd
# Reading tweets from Adrian Bailey
# Reading tweets from Afzal Khan
# Reading tweets from Alan Campbell
# Reading tweets from Albert Owen
# Reading tweets from Alex Cunningham
# Reading tweets from Alex Norris
# Reading tweets from Alex Sobel
# Reading tweets from Alison McGovern
# Reading tweets from Andrew Gwynne
# Reading tweets from Andy McDonald
# Reading tweets from Andy Slaughter
# Reading tweets from Angela Eagle
# Reading tweets from Angela Rayner
# Reading tweets from Ann Clwyd
# Reading tweets from Anna McMorrin
# Reading tweets from Anna Turley
# Reading tweets from Anneliese Dodds
# Reading tweets from Bambos Charalambous
# Reading tweets from Barbara Keeley
# Reading tweets from Barry Gardiner
# Reading tweets from Barry Sheerman
# Reading tweets from Ben Bradshaw
# Reading tweets from Bill Esterson
# Reading tweets from Bridget Phillipson
# Reading tweets from Caroline Flint
# Reading tweets from Carolyn Harris
# Reading tweets from Cat Smith
# Reading tweets from Catherine McKinnell
# Reading tweets from Catherine West
# Reading tweets from Chi Onwurah
# Reading tweets from Chris Bryant
# Reading tweets from Chris Elmore
# Reading tweets from Chris Ruane
# Reading tweets from Christian Matheson
# Reading tweets from Christina Rees
# Reading tweets from Christopher Evans
# Reading tweets from Clive Efford
# Reading tweets from Clive Lewis
# Reading tweets from Conor McGinn
# Reading tweets from Dan Carden
# Reading tweets from Dan Jarvis
# Reading tweets from Daniel Zeichner
# Reading tweets from Danielle Rowley
# Reading tweets from Darren Jones
# Reading tweets from David Crausby
# Reading tweets from David Drew
# Reading tweets from David Hanson
# Reading tweets from David Lammy
# Reading tweets from Dawn Butler
# Reading tweets from Debbie Abrahams
# Reading tweets from Derek Twigg
# Reading tweets from Diana Johnson
# Reading tweets from Diane Abbott
# Reading tweets from Dr Alan Whitehead
# Reading tweets from Dr Roberta Blackman-Woods
# Reading tweets from Dr Rosena Allin-Khan
# Reading tweets from Dr Rupa Huq
# Reading tweets from Edward Miliband
# Reading tweets from Eleanor Smith
# Reading tweets from Ellie Reeves
# Reading tweets from Emily Thornberry
# Reading tweets from Emma Dent Coad
# Reading tweets from Emma Hardy
# Reading tweets from Emma Lewell-Buck
# Reading tweets from Emma Reynolds
# Reading tweets from Fabian Hamilton
# Reading tweets from Faisal Rashid
# Reading tweets from Gareth Snell
# Reading tweets from Gareth Thomas
# Reading tweets from Geoffrey Robinson
# Reading tweets from Geraint Davies
# Reading tweets from Gerald Jones
# Reading tweets from Gerard Killen
# Reading tweets from Gill Furniss
# Reading tweets from Gloria De Piero
# Reading tweets from Gordon Marsden
# Reading tweets from Graham Jones
# Twitter error response: status code = 401
# Reading tweets from Grahame Morris
# Reading tweets from Harriet Harman QC
# Reading tweets from Helen Goodman
# Reading tweets from Helen Hayes
# Reading tweets from Helen Jones
# Reading tweets from Hilary Benn
# Reading tweets from Holly Lynch
# Reading tweets from Hugh Gaffney
# Reading tweets from Ian C. Lucas
# Reading tweets from Ian Lavery
# Reading tweets from Ian Mearns
# Reading tweets from Ian Murray
# Reading tweets from Imran Hussain
# Reading tweets from Jack Dromey
# Reading tweets from James Frith
# Reading tweets from Janet Daby
# Reading tweets from Jeff Smith
# Reading tweets from Jenny Chapman
# Reading tweets from Jeremy Corbyn
# Reading tweets from Jess Phillips
# Reading tweets from Jessica Morden
# Reading tweets from Jim Cunningham
# Reading tweets from Jim Fitzpatrick
# Reading tweets from Jim McMahon
# Reading tweets from Jo Platt
# Reading tweets from Jo Stevens
# Reading tweets from John Cryer
# Reading tweets from John Healey
# Reading tweets from John Mann
# Reading tweets from John McDonnell
# Reading tweets from John Spellar
# Reading tweets from Jon Cruddas
# Reading tweets from Jon Trickett
# Reading tweets from Jonathan Ashworth
# Reading tweets from Jonathan Reynolds
# Reading tweets from Judith Cummins
# Reading tweets from Julie Cooper
# Reading tweets from Julie Elliott
# Reading tweets from Justin Madders
# Reading tweets from Karen Buck
# Reading tweets from Karen Lee
# Reading tweets from Karin Smyth
# Reading tweets from Karl Turner
# Reading tweets from Kate Green
# Reading tweets from Kate Hoey
# Reading tweets from Kate Hollern
# Reading tweets from Kate Osamor
# Reading tweets from Keir Starmer
# Reading tweets from Keith Vaz
# Reading tweets from Kerry McCarthy
# Reading tweets from Kevan Jones
# Reading tweets from Kevin Barron
# Reading tweets from Kevin Brennan
# Reading tweets from Khalid Mahmood
# Reading tweets from Laura Pidcock
# Reading tweets from Laura Smith
# Reading tweets from Lesley Laird
# Reading tweets from Liam Byrne
# Reading tweets from Lilian Greenwood
# Reading tweets from Lindsay Hoyle
# Reading tweets from Lisa Forbes
# Reading tweets from Lisa Nandy
# Reading tweets from Liz Kendall
# Reading tweets from Liz McInnes
# Reading tweets from Liz Twist
# Reading tweets from Lloyd Russell-Moyle
# Reading tweets from Louise Ellman
# Reading tweets from Louise Haigh
# Reading tweets from Lucy Powell
# Reading tweets from Luke Pollard
# Reading tweets from Lyn Brown
# Reading tweets from Madeleine Moon
# Reading tweets from Margaret Greenwood
# Reading tweets from Margaret Hodge
# Reading tweets from Maria Eagle
# Reading tweets from Marie Rimmer
# Reading tweets from Mark Hendrick
# Reading tweets from Mark Tami
# Reading tweets from Marsha de Cordova
# Reading tweets from Martin Whitfield
# Reading tweets from Mary Creagh
# Reading tweets from Mary Glindon
# Reading tweets from Matt Rodda
# Reading tweets from Matt Western
# Reading tweets from Matthew Pennycook
# Reading tweets from Meg Hillier
# Reading tweets from Melanie Onn
# Reading tweets from Mike Amesbury
# Reading tweets from Mike Hill
# Reading tweets from Mike Kane
# Reading tweets from Mohammad Yasin
# Reading tweets from Naz Shah
# Reading tweets from Neil Coyle
# Reading tweets from Nia Griffith
# Reading tweets from Nic Dakin
# Reading tweets from Nick Smith
# Reading tweets from Nick Thomas-Symonds
# Reading tweets from Owen Smith
# Reading tweets from Pat McFadden
# Reading tweets from Paul Blomfield
# Reading tweets from Paul Daniel Williams
# Reading tweets from Paul Sweeney
# Reading tweets from Paula Sherriff
# Reading tweets from Peter Dowd
# Reading tweets from Peter Kyle
# Reading tweets from Phil Wilson
# Reading tweets from Preet Gill
# Reading tweets from Rachael Maskell
# Reading tweets from Rachel Reeves
# Reading tweets from Rebecca Long-Bailey
# Reading tweets from Richard Burden
# Reading tweets from Richard Burgon
# Reading tweets from Roger Godsiff
# Reading tweets from Rosie Cooper
# Reading tweets from Rosie Duffield
# Reading tweets from Rushanara Ali
# Reading tweets from Ruth Cadbury
# Reading tweets from Ruth George
# Reading tweets from Ruth Jones
# Reading tweets from Ruth Smeeth
# Reading tweets from Sandy Martin
# Reading tweets from Sarah Champion
# Reading tweets from Sarah Jones
# Reading tweets from Seema Malhotra
# Reading tweets from Shabana Mahmood
# Reading tweets from Sharon Hodgson
# Reading tweets from Siobhain McDonagh
# Reading tweets from Stella Creasy
# Reading tweets from Stephanie Peacock
# Reading tweets from Stephen Doughty
# Reading tweets from Stephen Hepburn
# Reading tweets from Stephen Kinnock
# Reading tweets from Stephen Morgan
# Reading tweets from Stephen Timms
# Reading tweets from Stephen Twigg
# Reading tweets from Steve McCabe
# Reading tweets from Steve Reed
# Reading tweets from Sue Hayman
# Reading tweets from Susan Elan Jones
# Reading tweets from Tanmanjit Singh Dhesi
# Reading tweets from Teresa Pearce
# Reading tweets from Thangam Debbonaire
# Reading tweets from Thelma Walker
# Reading tweets from Toby Perkins
# Reading tweets from Tom Watson
# Reading tweets from Tonia Antoniazzi
# Reading tweets from Tony Lloyd
# Reading tweets from Tracy Brabin
# Reading tweets from Tulip Siddiq
# Reading tweets from Valerie Vaz
# Reading tweets from Vernon Coaker
# Reading tweets from Vicky Foxcroft
# Reading tweets from Virendra Sharma
# Reading tweets from Wayne David
# Reading tweets from Wes Streeting
# Reading tweets from Yasmin Qureshi
# Reading tweets from Yvette Cooper
# Reading tweets from Yvonne Fovargue
# Reading tweets from Alistair Carmichael
# Reading tweets from Christine Jardine
# Reading tweets from Chuka Umunna
# Reading tweets from Edward Davey
# Reading tweets from Jamie Stone
# Reading tweets from Jane Dodds
# Reading tweets from Jo Swinson
# Reading tweets from Layla Moran
# Reading tweets from Norman Lamb
# Reading tweets from Tim Farron
# Reading tweets from Tom Brake
# Reading tweets from Vincent Cable
# Reading tweets from Wera Hobhouse
# Reading tweets from Ben Lake
# Reading tweets from Hywel Williams
# Reading tweets from Jonathan Edwards
# Reading tweets from Liz Saville Roberts
# Reading tweets from Alan Brown
# Reading tweets from Alison Thewliss
# Reading tweets from Angela Crawley
# Reading tweets from Angus MacNeil
# Reading tweets from Brendan O'Hara
# Reading tweets from Carol Monaghan
# Reading tweets from Chris Law
# Reading tweets from Chris Stephens
# Reading tweets from David Linden
# Reading tweets from Deidre Brock
# Reading tweets from Douglas Chapman
# Reading tweets from Dr Lisa Cameron
# Reading tweets from Dr Philippa Whitford
# Reading tweets from Drew Hendry
# Reading tweets from Gavin Newlands
# Reading tweets from Hannah Bardell
# Reading tweets from Ian Blackford
# Reading tweets from Joanna Cherry QC
# Reading tweets from John Mc Nally
# Reading tweets from Kirsty Blackman
# Reading tweets from Marion Fellows
# Reading tweets from Martin Docherty-Hughes
# Reading tweets from Martyn Day
# Reading tweets from Mhairi Black
# Reading tweets from Neil Gray
# Reading tweets from Patricia Gibson
# Reading tweets from Patrick Grady
# Reading tweets from Pete Wishart
# Reading tweets from Peter Grant
# Reading tweets from Ronnie Cowan
# Reading tweets from Stephen Gethins
# Reading tweets from Stewart Hosie
# Reading tweets from Stewart Malcolm McDonald
# Reading tweets from Stuart C. McDonald
# Reading tweets from Tommy Sheppard
# Reading tweets from Christopher Hazzard
# Reading tweets from Elisha McCallion
# Reading tweets from Francie Molloy
# Reading tweets from Michelle Gildernew
# Reading tweets from Mickey Brady
# Reading tweets from Órfhlaith Begley
# Reading tweets from Paul Maskey
# Reading tweets from Ann Coffey
# Reading tweets from Anna Soubry
# Reading tweets from Chris Leslie
# Reading tweets from Joan Ryan
# Reading tweets from Mike Gapes
