# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, TfidfTransformer, CountVectorizer
from sklearn.cluster import KMeans

# %load_ext autoreload
# %autoreload 2

from util import listdir_fullpath
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
doc_path = './raw-text/'

filelist = listdir_fullpath(doc_path)

# Initier tf-idf vectorisering
vectorizer = TfidfVectorizer('filename')

# Lagre tf-idf score i X
X = vectorizer.fit_transform(filelist)

# Konvertér X til dataframe
df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names())
df
# Out:
#            00       000  00003      0001  0009     000ha  000m  001  \
# 0    0.000000  0.002267    0.0  0.000000   0.0  0.000000   0.0  0.0
# 1    0.000000  0.004194    0.0  0.000000   0.0  0.000000   0.0  0.0
# 2    0.000000  0.002584    0.0  0.000000   0.0  0.000000   0.0  0.0
# 3    0.000000  0.001412    0.0  0.000000   0.0  0.000000   0.0  0.0
# 4    0.000000  0.024143    0.0  0.000000   0.0  0.000000   0.0  0.0
# 5    0.000000  0.020460    0.0  0.011944   0.0  0.000000   0.0  0.0
# 6    0.000000  0.014947    0.0  0.000000   0.0  0.000000   0.0  0.0
# 7    0.000000  0.000000    0.0  0.000000   0.0  0.000000   0.0  0.0
# 8    0.000000  0.006613    0.0  0.000000   0.0  0.000000   0.0  0.0
# 9    0.000000  0.005876    0.0  0.000000   0.0  0.000000   0.0  0.0
# 10   0.000000  0.018753    0.0  0.000000   0.0  0.000000   0.0  0.0
# 11   0.000000  0.000000    0.0  0.000000   0.0  0.000000   0.0  0.0
# 12   0.000000  0.009373    0.0  0.000000   0.0  0.000000   0.0  0.0
# ...

# %%
vectorizer.get_feature_names()
# Out:
# ['00',
#  '000',
#  '00003',
#  '0001',
#  '0009',
#  '000ha',
#  '000m',
#  '001',
#  '001109230',
#  '002',
#  '0023',
#  '0028',
#  '0029',
#  '003',
#  '004',
#  '005',
#  '006',
#  '007',
#  '008',
#  '00th',
#  '01',
#  '010',
#  '0101',
#  '010p1v2',
#  '010tv',
#  '011',
#  '0120',
#  '01252',
#  '013',
#  '014',
#  '015',
#  '016',
#  '017',
#  '018',
#  '02',
#  '020',
#  '0202676436875_le',
#  '021',
#  '022',
#  '024',
#  '025',
#  '027',
#  '0274',
#  '029',
#  '03',
#  '030',
#  '031',
#  '0319',
#  '032',
#  '033',
#  '035',
#  '0352',
#  '036',
#  '037',
#  '038',
#  '04',
#  '040',
#  '0401',
#  '043',
#  '044',
#  '045',
#  '047',
#  '048',
#  '05',
#  '050',
#  '051',
#  '0511',
#  '052',
#  '0530',
#  '0536',
#  '054',
#  '055',
#  '056',
#  '0584',
#  '059',
#  '06',
#  '060',
#  '061',
#  '063',
#  '065',
#  '0654',
#  '066',
#  '067',
#  '069',
#  '07',
#  '070',
#  '0703capmarkets_summ',
#  '071',
#  '0713',
#  '0723',
#  '073',
#  '075',
#  '076',
# ...
